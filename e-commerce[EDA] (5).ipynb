# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
cu=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_customers_dataset.csv")
gl=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_geolocation_dataset.csv")
oid=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_order_items_dataset.csv")
opd=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_order_payments_dataset.csv")
ord=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_order_reviews_dataset.csv")
od=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_orders_dataset.csv")
prd=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_products_dataset.csv")

# %%
cu
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city     customer_state
# ...

# %%
gl
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                              1037       -23.545621       -46.639292
# 1                              1046       -23.546081       -46.644820
# 2                              1046       -23.546129       -46.642951
# 3                              1041       -23.544392       -46.639499
# 4                              1035       -23.541578       -46.641607
# ...                             ...              ...              ...
# 738327                        99965       -28.180655       -52.034367
# 738328                        99950       -28.072188       -52.011272
# 738329                        99950       -28.068864       -52.012964
# 738330                        99950       -28.068639       -52.010705
# 738331                        99980       -28.388932       -51.846871
#
#        geolocation_city geolocation_state
# 0             sao paulo                SP
# ...

# %%
oid
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
opd
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
ord
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
od
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
prd
# Out:
#                              product_id        product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                      perfume
# 1      3aa071139cb16b67ca9e5dea641aaa2f                          art
# 2      96bd76ec8810374ed1b65e291975717f               sports_leisure
# 3      cef67bcfe19066a932b7673e239eb23d                         baby
# 4      9dc1a7de274444849c219cff195d0b71               home_utilities
# ...                                 ...                          ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0              furniture_decor
# 32947  bf4538d88321d0fd4412a93c974510e6  construction_tools_lighting
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c               bed_bath_table
# 32949  83808703fc0706a22e264b9d75f04a2e      electronics_accessories
# 32950  106392145fca363410d287a815be6de4               bed_bath_table
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# ...

# %%
cu.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
cu.shape
# Out:
# (99441, 5)

# %%
cu.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca      Sao Paulo
# 1                      9790  sao bernardo do campo      Sao Paulo
# 2                      1151              sao paulo      Sao Paulo
# 3                      8775        mogi das cruzes      Sao Paulo
# 4                     13056               campinas      Sao Paulo

# %%
cu.tail()
# Out:
#                             customer_id                customer_unique_id  \
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix    customer_city     customer_state
# 99436                      3937        sao paulo          Sao Paulo
# 99437                      6764  taboao da serra          Sao Paulo
# 99438                     60115        fortaleza              Ceara
# 99439                     92120           canoas  Rio Grande do Sul
# 99440                      6703            cotia          Sao Paulo

# %%
cu.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
cu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
cu['customer_city']=cu['customer_city'].astype('string')

# %%
cu['customer_state']=cu['customer_state'].astype('string')

# %%
cu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  string
#  4   customer_state            99441 non-null  string
# dtypes: int64(1), object(2), string(2)
# memory usage: 3.8+ MB

# %%
cu.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
cu.duplicated().sum()
# Out:
# np.int64(0)

# %%
cu['customer_city'].unique()
# Out:
# <StringArray>
# [               'franca', 'sao bernardo do campo',             'sao paulo',
#        'mogi das cruzes',              'campinas',        'jaragua do sul',
#                'timoteo',              'curitiba',        'belo horizonte',
#          'montes claros',
#  ...
#               'balbinos',          'serra bonita',          'venda branca',
#            'sanga puita',               'queiroz',                'siriji',
#    'natividade da serra',          'monte bonito',            'sao rafael',
#      'eugenio de castro']
# Length: 4119, dtype: string

# %%
cu['customer_state'].unique()
# Out:
# <StringArray>
# [          'Sao Paulo',      'Santa Catarina',        'Minas Gerais',
#               'Parana',      'Rio de Janeiro',   'Rio Grande do Sul',
#                 'Para',               'Goias',      'Espirito Santo',
#                'Bahia',            'Maranhao',  'Mato Grosso do Sul',
#                'Ceara',    'Distrito Federal', 'Rio Grande do Norte',
#           'Pernambuco',         'Mato Grosso',            'Amazonas',
#                'Amapa',             'Alagoas',            'Rondonia',
#              'Paraiba',           'Tocantins',               'Piaui',
#                 'Acre',             'Sergipe',             'Roraima']
# Length: 27, dtype: string

# %%
cu['customer_state'].value_counts()
# Out:
# customer_state
# Sao Paulo              41746
# Rio de Janeiro         12852
# Minas Gerais           11635
# Rio Grande do Sul       5466
# Parana                  5045
# Santa Catarina          3637
# Bahia                   3380
# Distrito Federal        2140
# Espirito Santo          2033
# Goias                   2020
# Pernambuco              1652
# Ceara                   1336
# Para                     975
# Mato Grosso              907
# Maranhao                 747
# Mato Grosso do Sul       715
# Paraiba                  536
# Piaui                    495
# Rio Grande do Norte      485
# Alagoas                  413
# Sergipe                  350
# Tocantins                280
# Rondonia                 253
# Amazonas                 148
# Acre                      81
# Amapa                     68
# Roraima                   46
# Name: count, dtype: Int64

# %%
cu['customer_city'].value_counts()
# Out:
# customer_city
# sao paulo            15540
# rio de janeiro        6882
# belo horizonte        2773
# brasilia              2131
# curitiba              1521
#                      ...
# bequimao                 1
# andarai                  1
# vargem grande            1
# curvelandia              1
# eugenio de castro        1
# Name: count, Length: 4119, dtype: Int64

# %%
gl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738332 entries, 0 to 738331
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   geolocation_zip_code_prefix  738332 non-null  int64
#  1   geolocation_lat              738332 non-null  float64
#  2   geolocation_lng              738332 non-null  float64
#  3   geolocation_city             738332 non-null  object
#  4   geolocation_state            738332 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 28.2+ MB

# %%
gl['geolocation_city']=gl['geolocation_city'].astype('string')

# %%
gl['geolocation_state']=gl['geolocation_state'].astype('string')

# %%
gl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738332 entries, 0 to 738331
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   geolocation_zip_code_prefix  738332 non-null  int64
#  1   geolocation_lat              738332 non-null  float64
#  2   geolocation_lng              738332 non-null  float64
#  3   geolocation_city             738332 non-null  string
#  4   geolocation_state            738332 non-null  string
# dtypes: float64(2), int64(1), string(2)
# memory usage: 28.2 MB

# %%
gl.shape
# Out:
# (738332, 5)

# %%
gl.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
gl.duplicated().sum()
# Out:
# np.int64(0)

# %%
gl[gl.duplicated()]
# Out:
# Empty DataFrame
# Columns: [geolocation_zip_code_prefix, geolocation_lat, geolocation_lng, geolocation_city, geolocation_state]
# Index: []

# %%
gl=gl.drop_duplicates()

# %%
gl.duplicated().sum()
# Out:
# np.int64(0)

# %%
gl.shape
# Out:
# (738332, 5)

# %%
gl['geolocation_city'].value_counts()
# Out:
# geolocation_city
# sao paulo               79927
# rio de janeiro          35177
# são paulo               19718
# belo horizonte          19474
# curitiba                11263
#                         ...
# porto sao jose              1
# riachão do bacamarte        1
# riachao do bacamarte        1
# algodão de jandaíra         1
# luziapolis                  1
# Name: count, Length: 8011, dtype: Int64

# %%
gl['geolocation_state'].value_counts()
# Out:
# geolocation_state
# SP    285976
# MG    101353
# RJ     78836
# RS     48093
# PR     45059
# SC     30191
# BA     27720
# GO     15601
# PE     13162
# ES     12632
# CE      9541
# MT      9374
# DF      9080
# MS      8594
# PA      8551
# MA      6277
# PB      4787
# RN      4014
# PI      3592
# AL      3415
# TO      2977
# SE      2653
# RO      2523
# AM      1986
# AC      1039
# AP       738
# RR       568
# Name: count, dtype: Int64

# %%
oid.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
oid.shape
# Out:
# (112650, 7)

# %%
oid.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
oid.tail()
# Out:
#                                 order_id  order_item_id  \
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# ...

# %%
oid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
oid['shipping_limit_date']=pd.to_datetime(oid['shipping_limit_date'])

# %%
oid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
oid.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
oid.duplicated().sum()
# Out:
# np.int64(0)

# %%
opd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
opd.shape
# Out:
# (103886, 5)

# %%
opd.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
opd.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
opd.tail()
# Out:
#                                 order_id  payment_sequential payment_type  \
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# 103881                     1         363.31
# 103882                     2          96.80
# 103883                     1          47.77
# 103884                     5         369.54
# 103885                     1         191.58

# %%
opd.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
opd.duplicated().sum()
# Out:
# np.int64(0)

# %%
opd['payment_type'].unique()
# Out:
# array(['credit_card', 'boleto', 'voucher', 'debit_card', 'not_defined'],
#       dtype=object)

# %%
ord.shape
# Out:
# (99224, 7)

# %%
ord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
ord['review_creation_date']=pd.to_datetime(ord['review_creation_date'])

# %%
ord['review_answer_timestamp']=pd.to_datetime(ord['review_answer_timestamp'])

# %%
ord['review_comment_title']=ord['review_comment_title'].astype('string')

# %%
ord['review_comment_message']=ord['review_comment_message'].astype('string')

# %%
ord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  string
#  4   review_comment_message   40977 non-null  string
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(2), string(2)
# memory usage: 5.3+ MB

# %%
ord.describe()
# Out:
#        review_score           review_creation_date  \
# count  99224.000000                          99224
# mean       4.086421  2018-01-12 20:49:23.948238336
# min        1.000000            2016-10-02 00:00:00
# 25%        4.000000            2017-09-23 00:00:00
# 50%        5.000000            2018-02-02 00:00:00
# 75%        5.000000            2018-05-16 00:00:00
# max        5.000000            2018-08-31 00:00:00
# std        1.347579                            NaN
#
#              review_answer_timestamp
# count                          99224
# mean   2018-01-16 00:23:56.977938688
# min              2016-10-07 18:32:28
# 25%    2017-09-27 01:53:27.249999872
# 50%       2018-02-04 22:41:47.500000
# 75%       2018-05-20 12:11:21.500000
# max              2018-10-29 12:27:35
# std                              NaN

# %%
ord.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
ord['review_comment_title']=ord['review_comment_title'].fillna('no title')

# %%
ord['review_comment_message']=ord['review_comment_message'].fillna('no message')

# %%
ord.isnull().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
ord.duplicated().sum()
# Out:
# np.int64(0)

# %%
od.shape
# Out:
# (99441, 8)

# %%
od.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
od['order_status']=od['order_status'].astype('string')

# %%
od['order_purchase_timestamp']=pd.to_datetime(od['order_purchase_timestamp'])

# %%
od['order_approved_at']=pd.to_datetime(od['order_approved_at'])

# %%
od['order_delivered_carrier_date']=pd.to_datetime(od['order_delivered_carrier_date'])

# %%
od['order_delivered_customer_date']=pd.to_datetime(od['order_delivered_customer_date'])

# %%
od['order_estimated_delivery_date']=pd.to_datetime(od['order_estimated_delivery_date'])

# %%
od.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  string
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(2), string(1)
# memory usage: 6.1+ MB

# %%
od.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
od.duplicated().sum()
# Out:
# np.int64(0)

# %%
od['order_status'].unique()
# Out:
# <StringArray>
# [  'delivered',    'invoiced',     'shipped',  'processing', 'unavailable',
#     'canceled',     'created',    'approved']
# Length: 8, dtype: string

# %%
prd.shape
# Out:
# (32951, 9)

# %%
prd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
prd['product_category_name']=prd['product_category_name'].astype('string')

# %%
prd['product_name_lenght']=prd['product_name_lenght'].astype('Int64')

# %%
prd['product_description_lenght']=prd['product_description_lenght'].astype('Int64')

# %%
prd['product_photos_qty']=prd['product_photos_qty'].astype('Int64')

# %%
prd['product_weight_g']=prd['product_weight_g'].astype('Int64')

# %%
prd['product_length_cm']=prd['product_length_cm'].astype('Int64')

# %%
prd['product_height_cm']=prd['product_height_cm'].astype('Int64')

# %%
prd['product_width_cm']=prd['product_width_cm'].astype('Int64')

# %%
prd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  string
#  2   product_name_lenght         32341 non-null  Int64
#  3   product_description_lenght  32341 non-null  Int64
#  4   product_photos_qty          32341 non-null  Int64
#  5   product_weight_g            32949 non-null  Int64
#  6   product_length_cm           32949 non-null  Int64
#  7   product_height_cm           32949 non-null  Int64
#  8   product_width_cm            32949 non-null  Int64
# dtypes: Int64(7), object(1), string(1)
# memory usage: 2.5+ MB

# %%
prd.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
(prd.isnull().sum()/len(prd))*100
# Out:
# product_id                    0.000000
# product_category_name         1.851234
# product_name_lenght           1.851234
# product_description_lenght    1.851234
# product_photos_qty            1.851234
# product_weight_g              0.006070
# product_length_cm             0.006070
# product_height_cm             0.006070
# product_width_cm              0.006070
# dtype: float64

# %%
cu.to_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_customers_dataset_1.csv", index=False)

# %%
gl.to_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_geolocation_dataset_1.csv", index=False)

# %%
oid.to_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_order_items_dataset_1.csv", index=False)

# %%
opd.to_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_order_payments_dataset_1.csv", index=False)

# %%
ord.to_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_order_reviews_dataset_1.csv", index=False)

# %%
od.to_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_orders_dataset_1.csv", index=False)

# %%
prd.to_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_products_dataset_1.csv", index=False)

# %%
cuC=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_customers_dataset_1.csv")

# %%
glC=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_geolocation_dataset_1.csv")

# %%
oidC=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_order_items_dataset_1.csv")

# %%
opdC=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_order_payments_dataset_1.csv")

# %%
ordC=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_order_reviews_dataset_1.csv")

# %%
odC=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_orders_dataset_1.csv")

# %%
prdC=pd.read_csv(r"C:\Users\KISHORE\Desktop\E-COMMERCE DATA ANLYSIS PROJECT\olist_products_dataset_1.csv")

# %%
##creating master dataset

# %%
df = odC.merge(cu,on='customer_id',how='left')

df = df.merge(ordC,on='order_id',how='left')

df = df.merge(oidC,on='order_id',how='left')

df = df.merge(opdC,on='order_id',how='left')

df = df.merge(prdC,on='product_id',how='left')

# %%
df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 119138  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 119139  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 119140  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119141  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119142  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 177
# order_delivered_carrier_date     2086
# order_delivered_customer_date    3421
# order_estimated_delivery_date       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# review_id                         997
# review_score                      997
# review_comment_title              997
# review_comment_message            997
# review_creation_date              997
# review_answer_timestamp           997
# order_item_id                     833
# product_id                        833
# seller_id                         833
# shipping_limit_date               833
# price                             833
# freight_value                     833
# payment_sequential                  3
# ...

# %%
df.shape
# Out:
# (119143, 36)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['order_id'].nunique()
# Out:
# 99441

# %%
df['price'].sum()
# Out:
# np.float64(14273699.650000002)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 36 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119143 non-null  object
#  1   customer_id                    119143 non-null  object
#  2   order_status                   119143 non-null  object
#  3   order_purchase_timestamp       119143 non-null  object
#  4   order_approved_at              118966 non-null  object
#  5   order_delivered_carrier_date   117057 non-null  object
#  6   order_delivered_customer_date  115722 non-null  object
#  7   order_estimated_delivery_date  119143 non-null  object
#  8   customer_unique_id             119143 non-null  object
#  9   customer_zip_code_prefix       119143 non-null  int64
#  10  customer_city                  119143 non-null  string
#  11  customer_state                 119143 non-null  string
# ...

# %%
prd['product_category_name'].unique()
# Out:
# array(['perfume', 'art', 'sports_leisure', 'baby', 'home_utilities',
#        'musical_instruments', 'cool_stuff', 'furniture_decor',
#        'home_appliances', 'toys', 'bed_bath_table',
#        'construction_tools_safety', 'electronics_accessories',
#        'health_beauty', 'luggage_accessories', 'garden_tools',
#        'office_furniture', 'automotive', 'electronics', 'fashion_shoes',
#        'telephony', 'stationery', 'fashion_bags_accessories', 'computers',
#        'home_construction', 'watches_gifts',
#        'construction_tools_construction', 'pet_shop', 'small_appliances',
#        'agro_industry_commerce', nan, 'living_room_furniture',
#        'signaling_safety', 'air_conditioning', 'consoles_games',
#        'books_general_interest', 'construction_tools_tools',
#        'fashion_underwear_beach', 'mens_clothing',
#        'kitchen_dining_garden_furniture', 'industry_commerce_business',
#        'fixed_telephony', 'construction_tools_lighting',
# ...

# %%
category_translation = {
    'perfumaria': 'perfume',
    'artes': 'art',
    'esporte_lazer': 'sports_leisure',
    'bebes': 'baby',
    'utilidades_domesticas': 'home_utilities',
    'instrumentos_musicais': 'musical_instruments',
    'cool_stuff': 'cool_stuff',
    'moveis_decoracao': 'furniture_decor',
    'eletrodomesticos': 'home_appliances',
    'brinquedos': 'toys',
    'cama_mesa_banho': 'bed_bath_table',
    'construcao_ferramentas_seguranca': 'construction_tools_safety',
    'informatica_acessorios': 'electronics_accessories',
    'beleza_saude': 'health_beauty',
    'malas_acessorios': 'luggage_accessories',
    'ferramentas_jardim': 'garden_tools',
    'moveis_escritorio': 'office_furniture',
    'automotivo': 'automotive',
    'eletronicos': 'electronics',
    'fashion_calcados': 'fashion_shoes',
    'telefonia': 'telephony',
    'papelaria': 'stationery',
    'fashion_bolsas_e_acessorios': 'fashion_bags_accessories',
    'pcs': 'computers',
    'casa_construcao': 'home_construction',
    'relogios_presentes': 'watches_gifts',
    'construcao_ferramentas_construcao': 'construction_tools_construction',
    'pet_shop': 'pet_shop',
    'eletroportateis': 'small_appliances',
    'agro_industria_e_comercio': 'agro_industry_commerce',
    'moveis_sala': 'living_room_furniture',
    'sinalizacao_e_seguranca': 'signaling_safety',
    'climatizacao': 'air_conditioning',
    'consoles_games': 'consoles_games',
    'livros_interesse_geral': 'books_general_interest',
    'construcao_ferramentas_ferramentas': 'construction_tools_tools',
    'fashion_underwear_e_moda_praia': 'fashion_underwear_beach',
    'fashion_roupa_masculina': 'mens_clothing',
    'moveis_cozinha_area_de_servico_jantar_e_jardim': 'kitchen_dining_garden_furniture',
    'industria_comercio_e_negocios': 'industry_commerce_business',
    'telefonia_fixa': 'fixed_telephony',
    'construcao_ferramentas_iluminacao': 'construction_tools_lighting',
    'livros_tecnicos': 'technical_books',
    'eletrodomesticos_2': 'home_appliances_2',
    'artigos_de_festas': 'party_supplies',
    'bebidas': 'drinks',
    'market_place': 'marketplace',
    'la_cuisine': 'kitchen_gourmet',
    'construcao_ferramentas_jardim': 'construction_tools_garden',
    'fashion_roupa_feminina': 'womens_clothing',
    'casa_conforto': 'home_comfort',
    'audio': 'audio',
    'alimentos_bebidas': 'food_drinks',
    'musica': 'music',
    'alimentos': 'food',
    'tablets_impressao_imagem': 'tablets_printing_imaging',
    'livros_importados': 'imported_books',
    'portateis_casa_forno_e_cafe': 'portable_home_oven_coffee',
    'fashion_esporte': 'sports_fashion',
    'artigos_de_natal': 'christmas_supplies',
    'fashion_roupa_infanto_juvenil': 'kids_clothing',
    'dvds_blu_ray': 'dvds_blu_ray',
    'artes_e_artesanato': 'arts_crafts',
    'pc_gamer': 'gaming_pc',
    'moveis_quarto': 'bedroom_furniture',
    'cine_foto': 'cinema_photo',
    'fraldas_higiene': 'diapers_hygiene',
    'flores': 'flowers',
    'casa_conforto_2': 'home_comfort_2',
    'portateis_cozinha_e_preparadores_de_alimentos': 'portable_kitchen_food_processors',
    'seguros_e_servicos': 'insurance_services',
    'moveis_colchao_e_estofado': 'mattress_upholstery',
    'cds_dvds_musicais': 'cds_dvds_music'
}

# %%
prd['product_category_name'] = prd['product_category_name'].map(category_translation)

# %%
prd['product_category_name'].unique()
# Out:
# array(['perfume', 'art', 'sports_leisure', 'baby', 'home_utilities',
#        'musical_instruments', 'cool_stuff', 'furniture_decor',
#        'home_appliances', 'toys', 'bed_bath_table',
#        'construction_tools_safety', 'electronics_accessories',
#        'health_beauty', 'luggage_accessories', 'garden_tools',
#        'office_furniture', 'automotive', 'electronics', 'fashion_shoes',
#        'telephony', 'stationery', 'fashion_bags_accessories', 'computers',
#        'home_construction', 'watches_gifts',
#        'construction_tools_construction', 'pet_shop', 'small_appliances',
#        'agro_industry_commerce', nan, 'living_room_furniture',
#        'signaling_safety', 'air_conditioning', 'consoles_games',
#        'books_general_interest', 'construction_tools_tools',
#        'fashion_underwear_beach', 'mens_clothing',
#        'kitchen_dining_garden_furniture', 'industry_commerce_business',
#        'fixed_telephony', 'construction_tools_lighting',
# ...

# %%
cu['customer_state'].unique()
# Out:
# array(['SP', 'SC', 'MG', 'PR', 'RJ', 'RS', 'PA', 'GO', 'ES', 'BA', 'MA',
#        'MS', 'CE', 'DF', 'RN', 'PE', 'MT', 'AM', 'AP', 'AL', 'RO', 'PB',
#        'TO', 'PI', 'AC', 'SE', 'RR'], dtype=object)

# %%
state_mapping = {
    'SP': 'Sao Paulo',
    'SC': 'Santa Catarina',
    'MG': 'Minas Gerais',
    'PR': 'Parana',
    'RJ': 'Rio de Janeiro',
    'RS': 'Rio Grande do Sul',
    'PA': 'Para',
    'GO': 'Goias',
    'ES': 'Espirito Santo',
    'BA': 'Bahia',
    'MA': 'Maranhao',
    'MS': 'Mato Grosso do Sul',
    'CE': 'Ceara',
    'DF': 'Distrito Federal',
    'RN': 'Rio Grande do Norte',
    'PE': 'Pernambuco',
    'MT': 'Mato Grosso',
    'AM': 'Amazonas',
    'AP': 'Amapa',
    'AL': 'Alagoas',
    'RO': 'Rondonia',
    'PB': 'Paraiba',
    'TO': 'Tocantins',
    'PI': 'Piaui',
    'AC': 'Acre',
    'SE': 'Sergipe',
    'RR': 'Roraima'
}

# %%
cu['customer_state'] = cu['customer_state'].replace(state_mapping)

# %%
# univariate analysis

df['payment_type'].value_counts()
# Out:
# payment_type
# credit_card    87776
# boleto         23190
# voucher         6465
# debit_card      1706
# not_defined        3
# Name: count, dtype: int64

# %%
df['price'].describe()
# Out:
# count    118310.000000
# mean        120.646603
# std         184.109691
# min           0.850000
# 25%          39.900000
# 50%          74.900000
# 75%         134.900000
# max        6735.000000
# Name: price, dtype: float64

# %%
#Bivariate Analysis

df.groupby('payment_type')['price'].mean()
# Out:
# payment_type
# boleto         104.526208
# credit_card    126.268956
# debit_card     108.507540
# not_defined           NaN
# voucher        105.061521
# Name: price, dtype: float64

# %%
#Time Analysis

df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df.groupby(df['order_purchase_timestamp'].dt.month).size()
# Out:
# order_purchase_timestamp
# 1      9690
# 2     10180
# 3     11858
# 4     11155
# 5     12743
# 6     11256
# 7     12325
# 8     12802
# 9      5209
# 10     6088
# 11     9191
# 12     6646
# dtype: int64

# %%
#Visualization

df['payment_type'].value_counts().plot(kind='bar')
plt.show()

# %%
#CUSTOMER ANALYSIS

#Top States
cuC['customer_state'].value_counts().head(10)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: count, dtype: int64

# %%
#Visualization

import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='customer_state', data=cuC, order=cuC['customer_state'].value_counts().index)
plt.xticks(rotation=90)
plt.title("Customers by State")
plt.show()

# %%
#ORDERS ANALYSIS

#Orders per Status

odC['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
#Visualization

sns.countplot(x='order_status', data=odC)
plt.xticks(rotation=45)
plt.title("Order Status Distribution")
plt.show()

# %%
#REVENUE ANALYSIS

#Revenue by State

df.groupby('customer_state')['price'].sum().sort_values(ascending=False).head(10)
# Out:
# customer_state
# Sao Paulo            5477008.74
# Rio de Janeiro       1921752.53
# Minas Gerais         1645847.27
# Rio Grande do Sul     791716.84
# Parana                708794.22
# Bahia                 543243.99
# Santa Catarina        539896.20
# Distrito Federal      315122.29
# Goias                 313198.27
# Espirito Santo        284771.30
# Name: price, dtype: float64

# %%
#Visualization

df.groupby('customer_state')['price'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("Top Revenue States")
plt.show()

# %%
#PAYMENT ANALYSIS

opdC['payment_type'].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
#Visualization

sns.countplot(x='payment_type', data=opdC)
plt.title("Payment Types")
plt.show()

# %%
#TIME ANALYSIS
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])

# %%
#Monthly trend

df['month'] = df['order_purchase_timestamp'].dt.to_period('M')

df.groupby('month').size().plot()
plt.title("Orders Trend Over Time")
plt.show()

# %%
#TOP PRODUCTS

df.groupby('product_id')['price'].sum().sort_values(ascending=False).head(10)
# Out:
# product_id
# bb50f2e236e5eea0100680137654686c    68810.00
# d6160fb7873f184099d9bc95e30376af    56948.83
# 6cdd53843498f92890544667809f1595    55779.90
# d1c427060a0f73f6b889a5c7c61f2ac4    49141.40
# 99a4788cb24856965c36a24e339b6058    46575.66
# 25c38557cf793876c5abdd5931f922db    44829.32
# 3dd2a17168ec895c781a9191c1e95ad7    41682.20
# aca2eb7d00ea1a7b8ebd4e68314663af    38248.20
# 53b36df67ebb7c41585e8d54d6772e08    38158.21
# 5f504b3a1c75b73d6151be81eb05bdc9    37733.90
# Name: price, dtype: float64
